# %%
from transformers import AutoTokenizer
from torch.utils.data import Dataset, DataLoader
import torch
import pickle
import transformer_lens
from torch.optim import AdamW
from os.path import join
from tqdm.auto import tqdm
import torch.nn as nn
import torch.nn.functional as F
from datasets import load_from_disk
from sklearn.model_selection import train_test_split
from dataclasses import dataclass
import argparse

import sys
sys.path.append('/home/leiyu/projects/def-yangxu/leiyu/circuit-discovery')
from dmc.circuit_gpt import *
from ioi_dataset import *

model_dir = '/home/leiyu/projects/def-yangxu/leiyu/LMs/'
model_name = 'gpt2-small'
n_ioi_data = 640

# %%
# path that stores gpt-small weights and gpt tokenizer
model_path = join(model_dir, model_name)
tokenizer = AutoTokenizer.from_pretrained(model_path)
tokenizer.pad_token = tokenizer.eos_token

# %%
# load IOI data
# Note that there are overlaps between train and test sets, 
# due to the way IOIDataset is constructed (randomly sample N items)
ds = IOIGeneratorDataset(prompt_type="ABC", N=n_ioi_data, tokenizer=tokenizer)
ioi_ds = IOIFullModelDataset(prepare_ioi_data_for_clm(ds.ioi_prompts))

# %%
ioi_ds[0]
# Out:
# {'prompt': 'Then, Jeremy, Stephen and Ashley went to the restaurant. Stephen and Ashley gave a necklace to',
#  'target good': ' Jeremy',
#  'target bad': ' Stephen'}

# %%
BABA_TEMPLATES = [
    "Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to ",
    "Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to ",
    "Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to ",
    "Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to ",
    "Then, [B] and [A] had a long argument, and afterwards [B] said to ",
    "After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to ",
    "When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to ",
    "When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to ",
    "While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to ",
    "While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to ",
    "After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to ",
    "Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to ",
    "Then, [B] and [A] had a long argument. Afterwards [B] said to ",
    "The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to ",
    "Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to ",
]


NAMES = [
    "Michael",
    "Christopher",
    "Jessica",
    "Matthew",
    "Ashley",
    "Jennifer",
    "Joshua",
    "Amanda",
    "Daniel",
    "David",
    "James",
    "Robert",
    "John",
    "Joseph",
    "Andrew",
    "Ryan",
    "Brandon",
    "Jason",
    "Justin",
    "Sarah",
    "William",
    "Jonathan",
    "Stephanie",
    "Brian",
    "Nicole",
    "Nicholas",
    "Anthony",
    "Heather",
    "Eric",
    "Elizabeth",
    "Adam",
    "Megan",
    "Melissa",
    "Kevin",
    "Steven",
    "Thomas",
    "Timothy",
    "Christina",
    "Kyle",
    "Rachel",
    "Laura",
    "Lauren",
    "Amber",
    "Brittany",
    "Danielle",
    "Richard",
    "Kimberly",
    "Jeffrey",
    "Amy",
    "Crystal",
    "Michelle",
    "Tiffany",
    "Jeremy",
    "Benjamin",
    "Mark",
    "Emily",
    "Aaron",
    "Charles",
    "Rebecca",
    "Jacob",
    "Stephen",
    "Patrick",
    "Sean",
    "Erin",
    "Jamie",
    "Kelly",
    "Samantha",
    "Nathan",
    "Sara",
    "Dustin",
    "Paul",
    "Angela",
    "Tyler",
    "Scott",
    "Katherine",
    "Andrea",
    "Gregory",
    "Erica",
    "Mary",
    "Travis",
    "Lisa",
    "Kenneth",
    "Bryan",
    "Lindsey",
    "Kristen",
    "Jose",
    "Alexander",
    "Jesse",
    "Katie",
    "Lindsay",
    "Shannon",
    "Vanessa",
    "Courtney",
    "Christine",
    "Alicia",
    "Cody",
    "Allison",
    "Bradley",
    "Samuel",
]

PLACES = [
    "store",
    "garden",
    "restaurant",
    "school",
    "hospital",
    "office",
    "house",
    "station",
]
OBJECTS = [
    "ring",
    "kiss",
    "bone",
    "basketball",
    "computer",
    "necklace",
    "drink",
    "snack",
]


def nth_repl(s, sub, repl, n):
    find = s.find(sub)
    # If find is not -1 we have found at least one match for the substring
    i = find != -1
    # loop util we find the nth or we find no match
    while find != -1 and i != n:
        # find + 1 means we start searching from after the last match
        find = s.find(sub, find + 1)
        i += 1
    # If i is equal to n we found nth match so replace
    if i == n:
        return s[:find] + repl + s[find+len(sub):]
    return s


def multiple_replace(replacements, text):
    # Create a regular expression from the dictionary keys
    regex = re.compile("(%s)" % "|".join(map(re.escape, replacements.keys())))
    # For each match, look-up corresponding value in dictionary
    return regex.sub(lambda mo: replacements[mo.group()], text) 


# random.choice(BABA_TEMPLATES)
# random.sample(NAMES, 3)

# %%
import random
N = 1000

# re.sub(pattern, repl, string, count=0, flags=0)

for i in range(N):
    template = random.choice(BABA_TEMPLATES)
    na, nb, nc = random.sample(NAMES, 3)
    place, obj = random.choice(PLACES), random.choice(OBJECTS)

    input_clean = multiple_replace({'[A]': na, '[B]': nb, '[OBJECT]': obj, '[PLACE]': place}, template)
    input_corrupt = nth_repl(input_clean, nb, nc, 2)

    print(template)
    print(na, nb, nc)
    print(input_clean)
    print(input_corrupt)
    print()
# Out:
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to
# Michael John Nicholas
# When John and Michael got a drink at the house, John decided to give it to
# When John and Michael got a drink at the house, Nicholas decided to give it to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Ryan Christina Matthew
# Afterwards, Christina and Ryan went to the school. Christina gave a ring to
# Afterwards, Christina and Ryan went to the school. Matthew gave a ring to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# Andrew Courtney Heather
# While Courtney and Andrew were working at the garden, Courtney gave a basketball to
# While Courtney and Andrew were working at the garden, Heather gave a basketball to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to
# Megan Joseph Katie
# When Joseph and Megan got a ring at the hospital, Joseph decided to give it to
# When Joseph and Megan got a ring at the hospital, Katie decided to give it to
#
# The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to
# Lindsey Dustin Patrick
# The school Dustin and Lindsey went to had a basketball. Dustin gave it to
# The school Dustin and Lindsey went to had a basketball. Patrick gave it to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Brandon Adam Eric
# After Adam and Brandon went to the house, Adam gave a ring to
# After Adam and Brandon went to the house, Eric gave a ring to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Gregory Alexander Elizabeth
# When Alexander and Gregory got a ring at the restaurant, Alexander decided to give the ring to
# When Alexander and Gregory got a ring at the restaurant, Elizabeth decided to give the ring to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Richard Robert Travis
# After Robert and Richard went to the hospital, Robert gave a necklace to
# After Robert and Richard went to the hospital, Travis gave a necklace to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Danielle Dustin Jeremy
# Then, Dustin and Danielle went to the store. Dustin gave a computer to
# Then, Dustin and Danielle went to the store. Jeremy gave a computer to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# Amanda Mary Lindsey
# While Mary and Amanda were working at the station, Mary gave a ring to
# While Mary and Amanda were working at the station, Lindsey gave a ring to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Steven Travis Jesse
# Then, Travis and Steven were thinking about going to the hospital. Travis wanted to give a snack to
# Then, Travis and Steven were thinking about going to the hospital. Jesse wanted to give a snack to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Samantha Andrew Alicia
# After the lunch, Andrew and Samantha went to the office. Andrew gave a drink to
# After the lunch, Andrew and Samantha went to the office. Alicia gave a drink to
#
# The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to
# Lisa Cody Amanda
# The store Cody and Lisa went to had a kiss. Cody gave it to
# The store Cody and Lisa went to had a kiss. Amanda gave it to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to
# Laura Sean Nicole
# When Sean and Laura got a bone at the school, Sean decided to give it to
# When Sean and Laura got a bone at the school, Nicole decided to give it to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Kristen David Amber
# Then, David and Kristen had a long argument, and afterwards David said to
# Then, David and Kristen had a long argument, and afterwards Amber said to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Jesse Michael Jamie
# Then, Michael and Jesse went to the hospital. Michael gave a drink to
# Then, Michael and Jesse went to the hospital. Jamie gave a drink to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Jonathan Tiffany Courtney
# When Tiffany and Jonathan got a basketball at the station, Tiffany decided to give the basketball to
# When Tiffany and Jonathan got a basketball at the station, Courtney decided to give the basketball to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Adam Andrew Allison
# Then, Andrew and Adam were thinking about going to the store. Andrew wanted to give a computer to
# Then, Andrew and Adam were thinking about going to the store. Allison wanted to give a computer to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Alicia Joshua Courtney
# When Joshua and Alicia got a ring at the restaurant, Joshua decided to give the ring to
# When Joshua and Alicia got a ring at the restaurant, Courtney decided to give the ring to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Heather Dustin Erin
# Afterwards, Dustin and Heather went to the school. Dustin gave a basketball to
# Afterwards, Dustin and Heather went to the school. Erin gave a basketball to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Jason Emily Samuel
# Then, Emily and Jason went to the garden. Emily gave a computer to
# Then, Emily and Jason went to the garden. Samuel gave a computer to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Matthew Brian Adam
# Afterwards, Brian and Matthew went to the garden. Brian gave a ring to
# Afterwards, Brian and Matthew went to the garden. Adam gave a ring to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Tyler Paul Dustin
# While Paul and Tyler were commuting to the hospital, Paul gave a basketball to
# While Paul and Tyler were commuting to the hospital, Dustin gave a basketball to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Charles Christopher Stephanie
# Then, Christopher and Charles had a long argument, and afterwards Christopher said to
# Then, Christopher and Charles had a long argument, and afterwards Stephanie said to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Dustin Michael Tiffany
# Then, Michael and Dustin went to the store. Michael gave a bone to
# Then, Michael and Dustin went to the store. Tiffany gave a bone to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Kenneth Brandon Stephanie
# Then, Brandon and Kenneth were thinking about going to the hospital. Brandon wanted to give a snack to
# Then, Brandon and Kenneth were thinking about going to the hospital. Stephanie wanted to give a snack to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Jesse Jason James
# Afterwards, Jason and Jesse went to the station. Jason gave a bone to
# Afterwards, Jason and Jesse went to the station. James gave a bone to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Brian Jacob Amy
# Then, Jacob and Brian had a lot of fun at the hospital. Jacob gave a ring to
# Then, Jacob and Brian had a lot of fun at the hospital. Amy gave a ring to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Jessica Jamie Stephen
# When Jamie and Jessica got a computer at the store, Jamie decided to give the computer to
# When Jamie and Jessica got a computer at the store, Stephen decided to give the computer to
#
# The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to
# Daniel Kristen Paul
# The store Kristen and Daniel went to had a necklace. Kristen gave it to
# The store Kristen and Daniel went to had a necklace. Paul gave it to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Stephen Erica Alicia
# Then, Erica and Stephen had a long argument, and afterwards Erica said to
# Then, Erica and Stephen had a long argument, and afterwards Alicia said to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to
# Megan Katherine Jonathan
# When Katherine and Megan got a basketball at the school, Katherine decided to give it to
# When Katherine and Megan got a basketball at the school, Jonathan decided to give it to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Erin Amber Rachel
# When Amber and Erin got a computer at the restaurant, Amber decided to give the computer to
# When Amber and Erin got a computer at the restaurant, Rachel decided to give the computer to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Dustin Paul Jonathan
# When Paul and Dustin got a snack at the hospital, Paul decided to give the snack to
# When Paul and Dustin got a snack at the hospital, Jonathan decided to give the snack to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# Alexander Michael Andrew
# While Michael and Alexander were working at the garden, Michael gave a drink to
# While Michael and Alexander were working at the garden, Andrew gave a drink to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Timothy Rachel Jennifer
# After Rachel and Timothy went to the hospital, Rachel gave a basketball to
# After Rachel and Timothy went to the hospital, Jennifer gave a basketball to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Jonathan Stephen David
# When Stephen and Jonathan got a basketball at the office, Stephen decided to give the basketball to
# When Stephen and Jonathan got a basketball at the office, David decided to give the basketball to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Rachel Brian Benjamin
# Afterwards, Brian and Rachel went to the garden. Brian gave a kiss to
# Afterwards, Brian and Rachel went to the garden. Benjamin gave a kiss to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# Michelle Lauren Kristen
# While Lauren and Michelle were working at the station, Lauren gave a ring to
# While Lauren and Michelle were working at the station, Kristen gave a ring to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Alexander Jeremy Erin
# Afterwards, Jeremy and Alexander went to the station. Jeremy gave a basketball to
# Afterwards, Jeremy and Alexander went to the station. Erin gave a basketball to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Crystal Tiffany Brittany
# Then, Tiffany and Crystal were thinking about going to the station. Tiffany wanted to give a kiss to
# Then, Tiffany and Crystal were thinking about going to the station. Brittany wanted to give a kiss to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Daniel Tyler Justin
# After the lunch, Tyler and Daniel went to the office. Tyler gave a ring to
# After the lunch, Tyler and Daniel went to the office. Justin gave a ring to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Jeffrey Robert Brandon
# Friends Robert and Jeffrey found a basketball at the restaurant. Robert gave it to
# Friends Robert and Jeffrey found a basketball at the restaurant. Brandon gave it to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Erica Amber Michelle
# Then, Amber and Erica went to the restaurant. Amber gave a computer to
# Then, Amber and Erica went to the restaurant. Michelle gave a computer to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Kelly Ashley James
# After the lunch, Ashley and Kelly went to the store. Ashley gave a drink to
# After the lunch, Ashley and Kelly went to the store. James gave a drink to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Alexander Daniel Amanda
# Then, Daniel and Alexander were thinking about going to the station. Daniel wanted to give a drink to
# Then, Daniel and Alexander were thinking about going to the station. Amanda wanted to give a drink to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# James Jonathan Jesse
# While Jonathan and James were working at the school, Jonathan gave a necklace to
# While Jonathan and James were working at the school, Jesse gave a necklace to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Jennifer Nicholas Samuel
# Then, Nicholas and Jennifer went to the garden. Nicholas gave a basketball to
# Then, Nicholas and Jennifer went to the garden. Samuel gave a basketball to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Lisa Eric Kristen
# After Eric and Lisa went to the garden, Eric gave a bone to
# After Eric and Lisa went to the garden, Kristen gave a bone to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Brittany Christopher Melissa
# After Christopher and Brittany went to the hospital, Christopher gave a drink to
# After Christopher and Brittany went to the hospital, Melissa gave a drink to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Crystal Kyle Joseph
# Afterwards, Kyle and Crystal went to the hospital. Kyle gave a kiss to
# Afterwards, Kyle and Crystal went to the hospital. Joseph gave a kiss to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Michael Megan Kristen
# After the lunch, Megan and Michael went to the office. Megan gave a necklace to
# After the lunch, Megan and Michael went to the office. Kristen gave a necklace to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Courtney Crystal Emily
# Then, Crystal and Courtney had a lot of fun at the office. Crystal gave a drink to
# Then, Crystal and Courtney had a lot of fun at the office. Emily gave a drink to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# Amanda Crystal Sarah
# While Crystal and Amanda were working at the house, Crystal gave a bone to
# While Crystal and Amanda were working at the house, Sarah gave a bone to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Brandon Richard Crystal
# Then, Richard and Brandon were thinking about going to the hospital. Richard wanted to give a snack to
# Then, Richard and Brandon were thinking about going to the hospital. Crystal wanted to give a snack to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Jesse Kristen Lindsay
# Afterwards, Kristen and Jesse went to the house. Kristen gave a basketball to
# Afterwards, Kristen and Jesse went to the house. Lindsay gave a basketball to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Crystal Bradley David
# Friends Bradley and Crystal found a ring at the store. Bradley gave it to
# Friends Bradley and Crystal found a ring at the store. David gave it to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Angela Katie Amber
# After the lunch, Katie and Angela went to the garden. Katie gave a snack to
# After the lunch, Katie and Angela went to the garden. Amber gave a snack to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Bryan Justin Lindsey
# While Justin and Bryan were commuting to the school, Justin gave a snack to
# While Justin and Bryan were commuting to the school, Lindsey gave a snack to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Daniel Mark Courtney
# Then, Mark and Daniel went to the restaurant. Mark gave a drink to
# Then, Mark and Daniel went to the restaurant. Courtney gave a drink to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Jose Erin Christopher
# Then, Erin and Jose had a lot of fun at the restaurant. Erin gave a snack to
# Then, Erin and Jose had a lot of fun at the restaurant. Christopher gave a snack to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Christina Nicole Erica
# After the lunch, Nicole and Christina went to the hospital. Nicole gave a ring to
# After the lunch, Nicole and Christina went to the hospital. Erica gave a ring to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Melissa Laura Christina
# Then, Laura and Melissa had a long argument, and afterwards Laura said to
# Then, Laura and Melissa had a long argument, and afterwards Christina said to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Katherine Sara Thomas
# After Sara and Katherine went to the store, Sara gave a basketball to
# After Sara and Katherine went to the store, Thomas gave a basketball to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# David Gregory Benjamin
# When Gregory and David got a ring at the school, Gregory decided to give the ring to
# When Gregory and David got a ring at the school, Benjamin decided to give the ring to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Erica Jeffrey Cody
# Then, Jeffrey and Erica had a lot of fun at the school. Jeffrey gave a computer to
# Then, Jeffrey and Erica had a lot of fun at the school. Cody gave a computer to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Brian Joseph Stephanie
# While Joseph and Brian were commuting to the house, Joseph gave a ring to
# While Joseph and Brian were commuting to the house, Stephanie gave a ring to
#
# Then, [B] and [A] had a long argument. Afterwards [B] said to
# Nicole Benjamin Anthony
# Then, Benjamin and Nicole had a long argument. Afterwards Benjamin said to
# Then, Benjamin and Nicole had a long argument. Afterwards Anthony said to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Sean Paul Patrick
# Then, Paul and Sean had a lot of fun at the school. Paul gave a snack to
# Then, Paul and Sean had a lot of fun at the school. Patrick gave a snack to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Jeffrey Megan Thomas
# Then, Megan and Jeffrey were thinking about going to the restaurant. Megan wanted to give a drink to
# Then, Megan and Jeffrey were thinking about going to the restaurant. Thomas wanted to give a drink to
#
# The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to
# Brandon Jamie Jason
# The hospital Jamie and Brandon went to had a drink. Jamie gave it to
# The hospital Jamie and Brandon went to had a drink. Jason gave it to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Amber Vanessa Mark
# Then, Vanessa and Amber had a long argument, and afterwards Vanessa said to
# Then, Vanessa and Amber had a long argument, and afterwards Mark said to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Rachel Amber Thomas
# Friends Amber and Rachel found a ring at the store. Amber gave it to
# Friends Amber and Rachel found a ring at the store. Thomas gave it to
#
# Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to
# Laura Amber Erica
# Then, Amber and Laura were working at the store. Amber decided to give a bone to
# Then, Amber and Laura were working at the store. Erica decided to give a bone to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Samuel Jessica Kristen
# Friends Jessica and Samuel found a drink at the station. Jessica gave it to
# Friends Jessica and Samuel found a drink at the station. Kristen gave it to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Megan Travis Kyle
# After the lunch, Travis and Megan went to the school. Travis gave a snack to
# After the lunch, Travis and Megan went to the school. Kyle gave a snack to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Robert Tiffany Thomas
# Then, Tiffany and Robert were thinking about going to the restaurant. Tiffany wanted to give a basketball to
# Then, Tiffany and Robert were thinking about going to the restaurant. Thomas wanted to give a basketball to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Bryan Stephanie Tiffany
# Then, Stephanie and Bryan went to the office. Stephanie gave a basketball to
# Then, Stephanie and Bryan went to the office. Tiffany gave a basketball to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Jacob Samuel Steven
# When Samuel and Jacob got a ring at the school, Samuel decided to give the ring to
# When Samuel and Jacob got a ring at the school, Steven decided to give the ring to
#
# Then, [B] and [A] had a long argument. Afterwards [B] said to
# Crystal Kristen Ashley
# Then, Kristen and Crystal had a long argument. Afterwards Kristen said to
# Then, Kristen and Crystal had a long argument. Afterwards Ashley said to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Erin Nicholas Anthony
# Afterwards, Nicholas and Erin went to the office. Nicholas gave a kiss to
# Afterwards, Nicholas and Erin went to the office. Anthony gave a kiss to
#
# The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to
# Christina Stephen Sean
# The hospital Stephen and Christina went to had a computer. Stephen gave it to
# The hospital Stephen and Christina went to had a computer. Sean gave it to
#
# Then, [B] and [A] had a long argument. Afterwards [B] said to
# Andrew Katie Benjamin
# Then, Katie and Andrew had a long argument. Afterwards Katie said to
# Then, Katie and Andrew had a long argument. Afterwards Benjamin said to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Jeffrey John Samantha
# Then, John and Jeffrey were thinking about going to the school. John wanted to give a necklace to
# Then, John and Jeffrey were thinking about going to the school. Samantha wanted to give a necklace to
#
# The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to
# Ryan Sean Samuel
# The store Sean and Ryan went to had a computer. Sean gave it to
# The store Sean and Ryan went to had a computer. Samuel gave it to
#
# Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to
# Allison Sean Alicia
# Then, Sean and Allison were working at the station. Sean decided to give a computer to
# Then, Sean and Allison were working at the station. Alicia decided to give a computer to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Vanessa Scott Jason
# Afterwards, Scott and Vanessa went to the house. Scott gave a necklace to
# Afterwards, Scott and Vanessa went to the house. Jason gave a necklace to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Amber Jennifer Daniel
# Afterwards, Jennifer and Amber went to the station. Jennifer gave a ring to
# Afterwards, Jennifer and Amber went to the station. Daniel gave a ring to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Andrea Tiffany Joshua
# Then, Tiffany and Andrea went to the office. Tiffany gave a drink to
# Then, Tiffany and Andrea went to the office. Joshua gave a drink to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Ryan Timothy Samantha
# Then, Timothy and Ryan had a long argument, and afterwards Timothy said to
# Then, Timothy and Ryan had a long argument, and afterwards Samantha said to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Daniel Ashley Paul
# Then, Ashley and Daniel were thinking about going to the garden. Ashley wanted to give a bone to
# Then, Ashley and Daniel were thinking about going to the garden. Paul wanted to give a bone to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Joseph Robert Tiffany
# Then, Robert and Joseph had a lot of fun at the garden. Robert gave a computer to
# Then, Robert and Joseph had a lot of fun at the garden. Tiffany gave a computer to
#
# Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to
# Rachel David Bradley
# Then, David and Rachel were working at the house. David decided to give a kiss to
# Then, David and Rachel were working at the house. Bradley decided to give a kiss to
#
# Then, [B] and [A] had a long argument. Afterwards [B] said to
# Lindsey John Brittany
# Then, John and Lindsey had a long argument. Afterwards John said to
# Then, John and Lindsey had a long argument. Afterwards Brittany said to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Nicholas Jessica Adam
# Then, Jessica and Nicholas went to the garden. Jessica gave a necklace to
# Then, Jessica and Nicholas went to the garden. Adam gave a necklace to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Sean Steven Sara
# Afterwards, Steven and Sean went to the garden. Steven gave a kiss to
# Afterwards, Steven and Sean went to the garden. Sara gave a kiss to
#
# Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to
# Michelle Brittany Samuel
# Then, Brittany and Michelle were working at the hospital. Brittany decided to give a ring to
# Then, Brittany and Michelle were working at the hospital. Samuel decided to give a ring to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Kyle Sara Michelle
# Friends Sara and Kyle found a kiss at the garden. Sara gave it to
# Friends Sara and Kyle found a kiss at the garden. Michelle gave it to
#
# The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to
# Andrew Erin Travis
# The house Erin and Andrew went to had a kiss. Erin gave it to
# The house Erin and Andrew went to had a kiss. Travis gave it to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Joshua Alicia Andrew
# After Alicia and Joshua went to the hospital, Alicia gave a kiss to
# After Alicia and Joshua went to the hospital, Andrew gave a kiss to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Michael Rachel John
# When Rachel and Michael got a basketball at the store, Rachel decided to give the basketball to
# When Rachel and Michael got a basketball at the store, John decided to give the basketball to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Sean Bryan Stephanie
# Afterwards, Bryan and Sean went to the station. Bryan gave a basketball to
# Afterwards, Bryan and Sean went to the station. Stephanie gave a basketball to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Jeffrey Jamie Shannon
# Then, Jamie and Jeffrey were thinking about going to the store. Jamie wanted to give a snack to
# Then, Jamie and Jeffrey were thinking about going to the store. Shannon wanted to give a snack to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to
# Eric Scott Sara
# When Scott and Eric got a computer at the restaurant, Scott decided to give it to
# When Scott and Eric got a computer at the restaurant, Sara decided to give it to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Amy Gregory Jesse
# Then, Gregory and Amy went to the store. Gregory gave a basketball to
# Then, Gregory and Amy went to the store. Jesse gave a basketball to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Jennifer Thomas Alicia
# Friends Thomas and Jennifer found a snack at the hospital. Thomas gave it to
# Friends Thomas and Jennifer found a snack at the hospital. Alicia gave it to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Patrick Timothy Joseph
# Then, Timothy and Patrick went to the office. Timothy gave a computer to
# Then, Timothy and Patrick went to the office. Joseph gave a computer to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Shannon Tiffany Ashley
# Then, Tiffany and Shannon went to the station. Tiffany gave a necklace to
# Then, Tiffany and Shannon went to the station. Ashley gave a necklace to
#
# Then, [B] and [A] had a long argument. Afterwards [B] said to
# Melissa Cody Samantha
# Then, Cody and Melissa had a long argument. Afterwards Cody said to
# Then, Cody and Melissa had a long argument. Afterwards Samantha said to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Stephanie Lindsey Dustin
# While Lindsey and Stephanie were commuting to the school, Lindsey gave a ring to
# While Lindsey and Stephanie were commuting to the school, Dustin gave a ring to
#
# Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to
# Amanda Gregory Dustin
# Then, Gregory and Amanda were working at the garden. Gregory decided to give a basketball to
# Then, Gregory and Amanda were working at the garden. Dustin decided to give a basketball to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Patrick Stephanie Danielle
# Friends Stephanie and Patrick found a drink at the school. Stephanie gave it to
# Friends Stephanie and Patrick found a drink at the school. Danielle gave it to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Tiffany Dustin Danielle
# When Dustin and Tiffany got a computer at the house, Dustin decided to give the computer to
# When Dustin and Tiffany got a computer at the house, Danielle decided to give the computer to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Amber Tyler Katie
# Then, Tyler and Amber had a long argument, and afterwards Tyler said to
# Then, Tyler and Amber had a long argument, and afterwards Katie said to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Crystal Kevin Lisa
# Then, Kevin and Crystal were thinking about going to the restaurant. Kevin wanted to give a drink to
# Then, Kevin and Crystal were thinking about going to the restaurant. Lisa wanted to give a drink to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Ashley Steven Samantha
# Afterwards, Steven and Ashley went to the garden. Steven gave a ring to
# Afterwards, Steven and Ashley went to the garden. Samantha gave a ring to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Brian Brittany Kyle
# Then, Brittany and Brian went to the office. Brittany gave a bone to
# Then, Brittany and Brian went to the office. Kyle gave a bone to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Michael Jason Mary
# While Jason and Michael were commuting to the office, Jason gave a snack to
# While Jason and Michael were commuting to the office, Mary gave a snack to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Paul Michelle Bradley
# When Michelle and Paul got a kiss at the garden, Michelle decided to give the kiss to
# When Michelle and Paul got a kiss at the garden, Bradley decided to give the kiss to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Kristen Tyler John
# Then, Tyler and Kristen went to the school. Tyler gave a basketball to
# Then, Tyler and Kristen went to the school. John gave a basketball to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Samantha Scott Lindsey
# When Scott and Samantha got a necklace at the office, Scott decided to give the necklace to
# When Scott and Samantha got a necklace at the office, Lindsey decided to give the necklace to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Tiffany Michael Lisa
# After Michael and Tiffany went to the station, Michael gave a necklace to
# After Michael and Tiffany went to the station, Lisa gave a necklace to
#
# Then, [B] and [A] had a long argument. Afterwards [B] said to
# Bryan Lindsay Amanda
# Then, Lindsay and Bryan had a long argument. Afterwards Lindsay said to
# Then, Lindsay and Bryan had a long argument. Afterwards Amanda said to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Crystal Jeremy Scott
# Then, Jeremy and Crystal had a lot of fun at the hospital. Jeremy gave a kiss to
# Then, Jeremy and Crystal had a lot of fun at the hospital. Scott gave a kiss to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Kelly Nicole Mary
# While Nicole and Kelly were commuting to the school, Nicole gave a bone to
# While Nicole and Kelly were commuting to the school, Mary gave a bone to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# Crystal James Dustin
# While James and Crystal were working at the station, James gave a bone to
# While James and Crystal were working at the station, Dustin gave a bone to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Ryan Lauren Jose
# Then, Lauren and Ryan went to the restaurant. Lauren gave a kiss to
# Then, Lauren and Ryan went to the restaurant. Jose gave a kiss to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Matthew Katherine Michelle
# Friends Katherine and Matthew found a kiss at the store. Katherine gave it to
# Friends Katherine and Matthew found a kiss at the store. Michelle gave it to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Courtney Patrick Katie
# After Patrick and Courtney went to the station, Patrick gave a snack to
# After Patrick and Courtney went to the station, Katie gave a snack to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# Christina Kelly Andrew
# While Kelly and Christina were working at the store, Kelly gave a bone to
# While Kelly and Christina were working at the store, Andrew gave a bone to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Samantha Andrea Richard
# Afterwards, Andrea and Samantha went to the office. Andrea gave a bone to
# Afterwards, Andrea and Samantha went to the office. Richard gave a bone to
#
# The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to
# Christine Rachel Alicia
# The house Rachel and Christine went to had a necklace. Rachel gave it to
# The house Rachel and Christine went to had a necklace. Alicia gave it to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to
# Andrew Amber Jose
# When Amber and Andrew got a snack at the house, Amber decided to give it to
# When Amber and Andrew got a snack at the house, Jose decided to give it to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Elizabeth Jessica Charles
# Afterwards, Jessica and Elizabeth went to the office. Jessica gave a snack to
# Afterwards, Jessica and Elizabeth went to the office. Charles gave a snack to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Kyle William Kenneth
# After William and Kyle went to the office, William gave a kiss to
# After William and Kyle went to the office, Kenneth gave a kiss to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Scott Jeffrey Michael
# Then, Jeffrey and Scott had a lot of fun at the station. Jeffrey gave a computer to
# Then, Jeffrey and Scott had a lot of fun at the station. Michael gave a computer to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Katie Sarah Rachel
# While Sarah and Katie were commuting to the station, Sarah gave a kiss to
# While Sarah and Katie were commuting to the station, Rachel gave a kiss to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# David Samantha Matthew
# Afterwards, Samantha and David went to the school. Samantha gave a basketball to
# Afterwards, Samantha and David went to the school. Matthew gave a basketball to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Scott Tyler Eric
# Then, Tyler and Scott had a long argument, and afterwards Tyler said to
# Then, Tyler and Scott had a long argument, and afterwards Eric said to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Andrew Shannon Richard
# After Shannon and Andrew went to the station, Shannon gave a ring to
# After Shannon and Andrew went to the station, Richard gave a ring to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Christina Katherine Rebecca
# After the lunch, Katherine and Christina went to the hospital. Katherine gave a necklace to
# After the lunch, Katherine and Christina went to the hospital. Rebecca gave a necklace to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# David Amy Stephanie
# When Amy and David got a snack at the restaurant, Amy decided to give the snack to
# When Amy and David got a snack at the restaurant, Stephanie decided to give the snack to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Steven Matthew Jacob
# Then, Matthew and Steven were thinking about going to the garden. Matthew wanted to give a basketball to
# Then, Matthew and Steven were thinking about going to the garden. Jacob wanted to give a basketball to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Michelle Richard Sara
# While Richard and Michelle were commuting to the house, Richard gave a bone to
# While Richard and Michelle were commuting to the house, Sara gave a bone to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Justin Tyler Katie
# Friends Tyler and Justin found a drink at the garden. Tyler gave it to
# Friends Tyler and Justin found a drink at the garden. Katie gave it to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Rachel Vanessa Andrea
# While Vanessa and Rachel were commuting to the garden, Vanessa gave a ring to
# While Vanessa and Rachel were commuting to the garden, Andrea gave a ring to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# Kimberly Mark Cody
# While Mark and Kimberly were working at the store, Mark gave a bone to
# While Mark and Kimberly were working at the store, Cody gave a bone to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Benjamin William Kevin
# While William and Benjamin were commuting to the restaurant, William gave a snack to
# While William and Benjamin were commuting to the restaurant, Kevin gave a snack to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Amy Joseph Danielle
# Then, Joseph and Amy went to the station. Joseph gave a computer to
# Then, Joseph and Amy went to the station. Danielle gave a computer to
#
# Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to
# Rachel Nathan Mary
# Then, Nathan and Rachel were working at the restaurant. Nathan decided to give a computer to
# Then, Nathan and Rachel were working at the restaurant. Mary decided to give a computer to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Amber Bryan Bradley
# After Bryan and Amber went to the garden, Bryan gave a necklace to
# After Bryan and Amber went to the garden, Bradley gave a necklace to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# David Bradley Brian
# While Bradley and David were working at the house, Bradley gave a snack to
# While Bradley and David were working at the house, Brian gave a snack to
#
# Then, [B] and [A] had a long argument. Afterwards [B] said to
# Lindsay Laura Jesse
# Then, Laura and Lindsay had a long argument. Afterwards Laura said to
# Then, Laura and Lindsay had a long argument. Afterwards Jesse said to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Lindsey Charles Erica
# After Charles and Lindsey went to the garden, Charles gave a necklace to
# After Charles and Lindsey went to the garden, Erica gave a necklace to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Aaron Cody Mary
# Friends Cody and Aaron found a necklace at the store. Cody gave it to
# Friends Cody and Aaron found a necklace at the store. Mary gave it to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Ryan Erica Crystal
# When Erica and Ryan got a computer at the office, Erica decided to give the computer to
# When Erica and Ryan got a computer at the office, Crystal decided to give the computer to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Jesse Travis Alexander
# Friends Travis and Jesse found a bone at the hospital. Travis gave it to
# Friends Travis and Jesse found a bone at the hospital. Alexander gave it to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Jacob Travis Danielle
# Then, Travis and Jacob had a lot of fun at the hospital. Travis gave a snack to
# Then, Travis and Jacob had a lot of fun at the hospital. Danielle gave a snack to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Andrew Sarah Jacob
# While Sarah and Andrew were commuting to the station, Sarah gave a basketball to
# While Sarah and Andrew were commuting to the station, Jacob gave a basketball to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Sean Alicia Brandon
# Afterwards, Alicia and Sean went to the restaurant. Alicia gave a drink to
# Afterwards, Alicia and Sean went to the restaurant. Brandon gave a drink to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Alicia Samantha William
# Afterwards, Samantha and Alicia went to the restaurant. Samantha gave a snack to
# Afterwards, Samantha and Alicia went to the restaurant. William gave a snack to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Allison Katherine Shannon
# While Katherine and Allison were commuting to the garden, Katherine gave a computer to
# While Katherine and Allison were commuting to the garden, Shannon gave a computer to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Andrew Christine Tyler
# After the lunch, Christine and Andrew went to the hospital. Christine gave a snack to
# After the lunch, Christine and Andrew went to the hospital. Tyler gave a snack to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Steven Kyle Lindsay
# Then, Kyle and Steven went to the restaurant. Kyle gave a kiss to
# Then, Kyle and Steven went to the restaurant. Lindsay gave a kiss to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# Lindsey Jessica Travis
# While Jessica and Lindsey were working at the garden, Jessica gave a bone to
# While Jessica and Lindsey were working at the garden, Travis gave a bone to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Kelly Megan Brandon
# After Megan and Kelly went to the hospital, Megan gave a necklace to
# After Megan and Kelly went to the hospital, Brandon gave a necklace to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Steven Kelly Jeffrey
# Then, Kelly and Steven had a long argument, and afterwards Kelly said to
# Then, Kelly and Steven had a long argument, and afterwards Jeffrey said to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Stephanie Courtney Jacob
# Then, Courtney and Stephanie were thinking about going to the office. Courtney wanted to give a basketball to
# Then, Courtney and Stephanie were thinking about going to the office. Jacob wanted to give a basketball to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Matthew Kenneth Jacob
# Then, Kenneth and Matthew were thinking about going to the garden. Kenneth wanted to give a basketball to
# Then, Kenneth and Matthew were thinking about going to the garden. Jacob wanted to give a basketball to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to
# Michael Jessica William
# When Jessica and Michael got a bone at the station, Jessica decided to give it to
# When Jessica and Michael got a bone at the station, William decided to give it to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Jacob Danielle Amber
# After Danielle and Jacob went to the hospital, Danielle gave a bone to
# After Danielle and Jacob went to the hospital, Amber gave a bone to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Joseph Dustin Christine
# When Dustin and Joseph got a snack at the garden, Dustin decided to give the snack to
# When Dustin and Joseph got a snack at the garden, Christine decided to give the snack to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Nicole Michelle Elizabeth
# Then, Michelle and Nicole went to the station. Michelle gave a bone to
# Then, Michelle and Nicole went to the station. Elizabeth gave a bone to
#
# The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to
# James Christine William
# The garden Christine and James went to had a drink. Christine gave it to
# The garden Christine and James went to had a drink. William gave it to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Nathan Elizabeth Andrea
# Friends Elizabeth and Nathan found a drink at the house. Elizabeth gave it to
# Friends Elizabeth and Nathan found a drink at the house. Andrea gave it to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Angela Jesse Matthew
# After the lunch, Jesse and Angela went to the store. Jesse gave a snack to
# After the lunch, Jesse and Angela went to the store. Matthew gave a snack to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Allison Vanessa Gregory
# When Vanessa and Allison got a drink at the station, Vanessa decided to give the drink to
# When Vanessa and Allison got a drink at the station, Gregory decided to give the drink to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Kenneth Anthony Jose
# Friends Anthony and Kenneth found a drink at the store. Anthony gave it to
# Friends Anthony and Kenneth found a drink at the store. Jose gave it to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Kenneth Courtney Elizabeth
# Then, Courtney and Kenneth had a lot of fun at the school. Courtney gave a basketball to
# Then, Courtney and Kenneth had a lot of fun at the school. Elizabeth gave a basketball to
#
# Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to
# Rebecca Eric Joshua
# Then, Eric and Rebecca were working at the hospital. Eric decided to give a computer to
# Then, Eric and Rebecca were working at the hospital. Joshua decided to give a computer to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# William Benjamin Erin
# Then, Benjamin and William had a long argument, and afterwards Benjamin said to
# Then, Benjamin and William had a long argument, and afterwards Erin said to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Adam Katie Sarah
# Afterwards, Katie and Adam went to the school. Katie gave a snack to
# Afterwards, Katie and Adam went to the school. Sarah gave a snack to
#
# Then, [B] and [A] had a long argument. Afterwards [B] said to
# Stephen Scott Charles
# Then, Scott and Stephen had a long argument. Afterwards Scott said to
# Then, Scott and Stephen had a long argument. Afterwards Charles said to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to
# Sara Sarah Benjamin
# When Sarah and Sara got a basketball at the restaurant, Sarah decided to give it to
# When Sarah and Sara got a basketball at the restaurant, Benjamin decided to give it to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Amanda Megan Lisa
# When Megan and Amanda got a ring at the house, Megan decided to give the ring to
# When Megan and Amanda got a ring at the house, Lisa decided to give the ring to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Jesse Crystal Travis
# Then, Crystal and Jesse had a long argument, and afterwards Crystal said to
# Then, Crystal and Jesse had a long argument, and afterwards Travis said to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# James Christina Rachel
# After the lunch, Christina and James went to the garden. Christina gave a basketball to
# After the lunch, Christina and James went to the garden. Rachel gave a basketball to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Kyle Erin Jeremy
# Then, Erin and Kyle had a lot of fun at the hospital. Erin gave a ring to
# Then, Erin and Kyle had a lot of fun at the hospital. Jeremy gave a ring to
#
# ...
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Heather Katie Nicholas
# Then, Katie and Heather were thinking about going to the station. Katie wanted to give a computer to
# Then, Katie and Heather were thinking about going to the station. Nicholas wanted to give a computer to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Jamie Kelly Mary
# After the lunch, Kelly and Jamie went to the school. Kelly gave a computer to
# After the lunch, Kelly and Jamie went to the school. Mary gave a computer to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Brandon Tyler Brian
# After the lunch, Tyler and Brandon went to the garden. Tyler gave a necklace to
# After the lunch, Tyler and Brandon went to the garden. Brian gave a necklace to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Cody Amanda Lauren
# Then, Amanda and Cody were thinking about going to the school. Amanda wanted to give a computer to
# Then, Amanda and Cody were thinking about going to the school. Lauren wanted to give a computer to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Daniel Allison Andrew
# After the lunch, Allison and Daniel went to the restaurant. Allison gave a necklace to
# After the lunch, Allison and Daniel went to the restaurant. Andrew gave a necklace to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Allison Bradley Sara
# Then, Bradley and Allison went to the store. Bradley gave a basketball to
# Then, Bradley and Allison went to the store. Sara gave a basketball to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Samuel Elizabeth Stephen
# After the lunch, Elizabeth and Samuel went to the office. Elizabeth gave a bone to
# After the lunch, Elizabeth and Samuel went to the office. Stephen gave a bone to
#
# Then, [B] and [A] had a long argument. Afterwards [B] said to
# Danielle Rebecca Christopher
# Then, Rebecca and Danielle had a long argument. Afterwards Rebecca said to
# Then, Rebecca and Danielle had a long argument. Afterwards Christopher said to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Stephanie Kristen Nicole
# While Kristen and Stephanie were commuting to the house, Kristen gave a basketball to
# While Kristen and Stephanie were commuting to the house, Nicole gave a basketball to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Jose Katherine Kenneth
# Afterwards, Katherine and Jose went to the store. Katherine gave a computer to
# Afterwards, Katherine and Jose went to the store. Kenneth gave a computer to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Mary Jonathan Lisa
# When Jonathan and Mary got a kiss at the house, Jonathan decided to give the kiss to
# When Jonathan and Mary got a kiss at the house, Lisa decided to give the kiss to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Kenneth Jamie Jose
# While Jamie and Kenneth were commuting to the office, Jamie gave a computer to
# While Jamie and Kenneth were commuting to the office, Jose gave a computer to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Steven Scott Gregory
# After the lunch, Scott and Steven went to the house. Scott gave a kiss to
# After the lunch, Scott and Steven went to the house. Gregory gave a kiss to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Jose Kristen Tyler
# After the lunch, Kristen and Jose went to the restaurant. Kristen gave a basketball to
# After the lunch, Kristen and Jose went to the restaurant. Tyler gave a basketball to
#
# The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to
# Melissa Jesse Andrew
# The station Jesse and Melissa went to had a drink. Jesse gave it to
# The station Jesse and Melissa went to had a drink. Andrew gave it to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to
# Laura Brandon Richard
# When Brandon and Laura got a drink at the house, Brandon decided to give it to
# When Brandon and Laura got a drink at the house, Richard decided to give it to
#
# Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to
# Ryan Kyle Kevin
# Then, Kyle and Ryan were working at the store. Kyle decided to give a computer to
# Then, Kyle and Ryan were working at the store. Kevin decided to give a computer to
#
# Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to
# Andrew Gregory Crystal
# Friends Gregory and Andrew found a computer at the school. Gregory gave it to
# Friends Gregory and Andrew found a computer at the school. Crystal gave it to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to
# Mary James Erin
# When James and Mary got a computer at the store, James decided to give it to
# When James and Mary got a computer at the store, Erin decided to give it to
#
# Then, [B] and [A] had a long argument. Afterwards [B] said to
# Sara Brittany Mark
# Then, Brittany and Sara had a long argument. Afterwards Brittany said to
# Then, Brittany and Sara had a long argument. Afterwards Mark said to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Jeremy Jacob Dustin
# Then, Jacob and Jeremy had a lot of fun at the store. Jacob gave a snack to
# Then, Jacob and Jeremy had a lot of fun at the store. Dustin gave a snack to
#
# Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to
# Michelle Charles Crystal
# Then, Charles and Michelle were working at the house. Charles decided to give a snack to
# Then, Charles and Michelle were working at the house. Crystal decided to give a snack to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to
# Lauren Erica Benjamin
# When Erica and Lauren got a necklace at the hospital, Erica decided to give it to
# When Erica and Lauren got a necklace at the hospital, Benjamin decided to give it to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Rachel Brittany Aaron
# After Brittany and Rachel went to the garden, Brittany gave a computer to
# After Brittany and Rachel went to the garden, Aaron gave a computer to
#
# After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Adam Michelle Samantha
# After the lunch, Michelle and Adam went to the hospital. Michelle gave a drink to
# After the lunch, Michelle and Adam went to the hospital. Samantha gave a drink to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Jonathan Christine Brandon
# Then, Christine and Jonathan had a long argument, and afterwards Christine said to
# Then, Christine and Jonathan had a long argument, and afterwards Brandon said to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Kenneth Benjamin Kimberly
# While Benjamin and Kenneth were commuting to the store, Benjamin gave a snack to
# While Benjamin and Kenneth were commuting to the store, Kimberly gave a snack to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Timothy Joseph Kyle
# Then, Joseph and Timothy had a lot of fun at the hospital. Joseph gave a bone to
# Then, Joseph and Timothy had a lot of fun at the hospital. Kyle gave a bone to
#
# The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to
# Gregory Nicole Jonathan
# The hospital Nicole and Gregory went to had a bone. Nicole gave it to
# The hospital Nicole and Gregory went to had a bone. Jonathan gave it to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# Jeremy Bradley Justin
# When Bradley and Jeremy got a ring at the school, Bradley decided to give the ring to
# When Bradley and Jeremy got a ring at the school, Justin decided to give the ring to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Kimberly Erica William
# Then, Erica and Kimberly went to the store. Erica gave a necklace to
# Then, Erica and Kimberly went to the store. William gave a necklace to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to
# Anthony Mark Erin
# When Mark and Anthony got a necklace at the restaurant, Mark decided to give it to
# When Mark and Anthony got a necklace at the restaurant, Erin decided to give it to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Danielle Nicholas Justin
# Then, Nicholas and Danielle were thinking about going to the garden. Nicholas wanted to give a kiss to
# Then, Nicholas and Danielle were thinking about going to the garden. Justin wanted to give a kiss to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Nicholas Brittany Emily
# Then, Brittany and Nicholas had a lot of fun at the station. Brittany gave a bone to
# Then, Brittany and Nicholas had a lot of fun at the station. Emily gave a bone to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Bradley Kimberly Jeffrey
# While Kimberly and Bradley were commuting to the restaurant, Kimberly gave a drink to
# While Kimberly and Bradley were commuting to the restaurant, Jeffrey gave a drink to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to
# Ashley Vanessa Jennifer
# When Vanessa and Ashley got a computer at the hospital, Vanessa decided to give it to
# When Vanessa and Ashley got a computer at the hospital, Jennifer decided to give it to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Samantha Melissa Kyle
# Then, Melissa and Samantha were thinking about going to the restaurant. Melissa wanted to give a drink to
# Then, Melissa and Samantha were thinking about going to the restaurant. Kyle wanted to give a drink to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Allison Megan Sara
# Then, Megan and Allison had a long argument, and afterwards Megan said to
# Then, Megan and Allison had a long argument, and afterwards Sara said to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# Daniel Lisa Courtney
# While Lisa and Daniel were working at the office, Lisa gave a kiss to
# While Lisa and Daniel were working at the office, Courtney gave a kiss to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Christine Kenneth Alexander
# After Kenneth and Christine went to the garden, Kenneth gave a kiss to
# After Kenneth and Christine went to the garden, Alexander gave a kiss to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Alexander Timothy Megan
# Then, Timothy and Alexander were thinking about going to the hospital. Timothy wanted to give a necklace to
# Then, Timothy and Alexander were thinking about going to the hospital. Megan wanted to give a necklace to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Scott Amber Brittany
# Then, Amber and Scott went to the house. Amber gave a bone to
# Then, Amber and Scott went to the house. Brittany gave a bone to
#
# The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to
# Ashley Michael Kevin
# The store Michael and Ashley went to had a basketball. Michael gave it to
# The store Michael and Ashley went to had a basketball. Kevin gave it to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# Jose Andrew Richard
# While Andrew and Jose were working at the garden, Andrew gave a computer to
# While Andrew and Jose were working at the garden, Richard gave a computer to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Sarah William Brian
# Then, William and Sarah went to the store. William gave a computer to
# Then, William and Sarah went to the store. Brian gave a computer to
#
# When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to
# William Ryan Erica
# When Ryan and William got a basketball at the hospital, Ryan decided to give the basketball to
# When Ryan and William got a basketball at the hospital, Erica decided to give the basketball to
#
# After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to
# Charles Kelly Paul
# After Kelly and Charles went to the store, Kelly gave a computer to
# After Kelly and Charles went to the store, Paul gave a computer to
#
# Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to
# Jamie Katie Melissa
# Then, Katie and Jamie had a lot of fun at the garden. Katie gave a necklace to
# Then, Katie and Jamie had a lot of fun at the garden. Melissa gave a necklace to
#
# While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to
# Robert Eric Jose
# While Eric and Robert were working at the store, Eric gave a ring to
# While Eric and Robert were working at the store, Jose gave a ring to
#
# Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Lindsey Ryan Kelly
# Then, Ryan and Lindsey went to the garden. Ryan gave a necklace to
# Then, Ryan and Lindsey went to the garden. Kelly gave a necklace to
#
# While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to
# Joseph Melissa Dustin
# While Melissa and Joseph were commuting to the garden, Melissa gave a basketball to
# While Melissa and Joseph were commuting to the garden, Dustin gave a basketball to
#
# Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to
# Anthony James Eric
# Then, James and Anthony were working at the restaurant. James decided to give a necklace to
# Then, James and Anthony were working at the restaurant. Eric decided to give a necklace to
#
# The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to
# Samuel Katie Erin
# The station Katie and Samuel went to had a bone. Katie gave it to
# The station Katie and Samuel went to had a bone. Erin gave it to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Christopher Tiffany Heather
# Afterwards, Tiffany and Christopher went to the house. Tiffany gave a basketball to
# Afterwards, Tiffany and Christopher went to the house. Heather gave a basketball to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Christine Laura Steven
# Afterwards, Laura and Christine went to the hospital. Laura gave a bone to
# Afterwards, Laura and Christine went to the hospital. Steven gave a bone to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Lindsey Aaron Mary
# Then, Aaron and Lindsey had a long argument, and afterwards Aaron said to
# Then, Aaron and Lindsey had a long argument, and afterwards Mary said to
#
# Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to
# Jennifer Gregory Joshua
# Afterwards, Gregory and Jennifer went to the store. Gregory gave a kiss to
# Afterwards, Gregory and Jennifer went to the store. Joshua gave a kiss to
#
# Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to
# Dustin Matthew Brandon
# Then, Matthew and Dustin were thinking about going to the school. Matthew wanted to give a bone to
# Then, Matthew and Dustin were thinking about going to the school. Brandon wanted to give a bone to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Sara Brandon Benjamin
# Then, Brandon and Sara had a long argument, and afterwards Brandon said to
# Then, Brandon and Sara had a long argument, and afterwards Benjamin said to
#
# Then, [B] and [A] had a long argument. Afterwards [B] said to
# John Brandon Kristen
# Then, Brandon and John had a long argument. Afterwards Brandon said to
# Then, Brandon and John had a long argument. Afterwards Kristen said to
#
# Then, [B] and [A] had a long argument. Afterwards [B] said to
# Kevin Joseph Cody
# Then, Joseph and Kevin had a long argument. Afterwards Joseph said to
# Then, Joseph and Kevin had a long argument. Afterwards Cody said to
#
# Then, [B] and [A] had a long argument, and afterwards [B] said to
# Brandon Danielle Ryan
# Then, Danielle and Brandon had a long argument, and afterwards Danielle said to
# Then, Danielle and Brandon had a long argument, and afterwards Ryan said to

# %%
# circuit_gpt initialization
device = torch.device('cuda')    
gpt_weights = torch.load(join(model_path, 'model_weights.pt')) 
circuit_gpt_config = CircuitGPTConfig(
    debug=False,
    use_weight_masks=False,
    use_edge_masks=False
)

circuit_gpt = CircuitGPT(circuit_gpt_config)
circuit_gpt.load_pretrained_weight(gpt_weights)
circuit_gpt.to(device);
circuit_gpt.eval();

# %%
circuit_gpt
# Out:
# CircuitGPT(
#   (embed): Embed()
#   (pos_embed): PosEmbed()
#   (ln_final): LayerNorm()
#   (unembed): Unembed()
#   (blocks): ModuleList(
#     (0-11): 12 x TransformerBlock(
#       (ln1): LayerNorm()
#       (attn): Attention()
#       (ln2): LayerNorm()
#       (mlp): MLP()
#     )
#   )
# )

# %%
from tqdm.auto import tqdm
from collections import OrderedDict
from typing import Dict, Callable
import torch

def remove_all_forward_hooks(model: torch.nn.Module) -> None:
    for name, child in model._modules.items():
        if child is not None:
            if hasattr(child, "_forward_hooks"):
                child._forward_hooks: Dict[int, Callable] = OrderedDict()
            remove_all_forward_hooks(child)
            

def make_output_hook(output_cache):
    def output_hook(module, inputs, outputs):
        # outputs_0 = untuple(outputs)
        print(outputs.shape)
        output_cache.append(outputs.detach().cpu()[0, -1])  # (n_child_node, h_dim)

    return output_hook
    

for _ in tqdm(range(1000)):

    # prepare inputs
    template = random.choice(BABA_TEMPLATES)
    na, nb, nc = random.sample(NAMES, 3)
    place, obj = random.choice(PLACES), random.choice(OBJECTS)

    prompt_clean = multiple_replace({'[A]': na, '[B]': nb, '[OBJECT]': obj, '[PLACE]': place}, template)
    prompt_corrupt = nth_repl(input_clean, nb, nc, 2)
    input_ids_clean = tokenizer(prompt_clean, return_tensors='pt')['input_ids']
    input_ids_corrupt = tokenizer(prompt_corrupt, return_tensors='pt')['input_ids']

    # register forward hooks to save resid stream outputs
    # forward_hooks = []
    # forward_output_dicts = {
    #     f'resid-{i}': []
    #     for i in range(12)
    # }
    # for i in range(12):
    #     forward_hook = circuit_gpt.blocks[i].register_forward_hook(
    #         make_output_hook(forward_output_dicts[f'resid-{i}'])
    #     )
    #     forward_hooks.append(forward_hook)

    with torch.no_grad():
        circuit_gpt(input_ids_clean.to(device))
        circuit_gpt(input_ids_corrupt.to(device))
        

    # for hook in forward_hooks:
    #     hook.remove()

    torch.cuda.empty_cache()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 49
#      47 with torch.no_grad():
#      48     circuit_gpt(input_ids_clean.to(device))
# ---> 49     circuit_gpt(input_ids_corrupt.to(device))
#      52 # for hook in forward_hooks:
#      53 #     hook.remove()
#      55 torch.cuda.empty_cache()
#
# File ~/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/projects/def-yangxu/leiyu/circuit-discovery/dmc/circuit_gpt.py:331, in CircuitGPT.forward(self, tokens, return_states)
#     328 residual = einops.rearrange(residual, "batch position d_model -> batch position 1 d_model")
#     330 for i, block in enumerate(self.blocks):
# --> 331     residual = block(residual)
#     333 if return_states:
#     334     return residual
#
# File ~/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/projects/def-yangxu/leiyu/circuit-discovery/dmc/circuit_gpt.py:227, in TransformerBlock.forward(self, resid_pre)
#     222 # print(f'sampled_edge_mask_mlp: {sampled_edge_mask_mlp}')
#     223 # print(f'self.edge_mask_attention_v_logits: {self.edge_mask_attention_v_logits.sum()}')
#     224
#     225 # resid_pre [batch, position, d_model, prev_head_idx]
#     226 masked_residuals_q = einsum("batch position prev_head_idx d_model, prev_head_idx n_heads -> batch position n_heads d_model", resid_pre, sampled_edge_mask_attentions_q)
# --> 227 masked_residuals_k = einsum("batch position prev_head_idx d_model, prev_head_idx n_heads -> batch position n_heads d_model", resid_pre, sampled_edge_mask_attentions_k)
#     228 masked_residuals_v = einsum("batch position prev_head_idx d_model, prev_head_idx n_heads -> batch position n_heads d_model", resid_pre, sampled_edge_mask_attentions_v)
#     230 normalized_resid_pre_q = self.ln1(masked_residuals_q, parallel=True)
#
# File ~/py310/lib/python3.10/site-packages/fancy_einsum/__init__.py:136, in einsum(equation, *operands)
#     134 backend = get_backend(operands[0])
#     135 new_equation = convert_equation(equation)
# --> 136 return backend.einsum(new_equation, *operands)
#
# File ~/py310/lib/python3.10/site-packages/fancy_einsum/__init__.py:54, in TorchBackend.einsum(self, equation, *operands)
#      53 def einsum(self, equation, *operands):
# ---> 54     return self.torch.einsum(equation, *operands)
#
# File ~/py310/lib/python3.10/site-packages/torch/functional.py:378, in einsum(*args)
#     373     return einsum(equation, *_operands)
#     375 if len(operands) <= 2 or not opt_einsum.enabled:
#     376     # the path for contracting 0 or 1 time(s) is already optimized
#     377     # or the user has disabled using opt_einsum
# --> 378     return _VF.einsum(equation, operands)  # type: ignore[attr-defined]
#     380 path = None
#     381 if opt_einsum.is_available():
#
# KeyboardInterrupt:

# %%
remove_all_forward_hooks(circuit_gpt)

# %%
input_ids_corrupt
# Out:
# tensor([[ 6423,    11, 39808,   290, 14328,   550,   257,   890,  4578,    11,
#            290, 12979, 39808,   531,   284,   220]])
